# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %%
maintenance_agent = Agent(
    name="Maintenance Assistant",
    instructions="""
    You are a helpful assistant providing maintenance support.
    You give concise answers.
    """,
)

# %%
with trace("Simple Maintenance Agent"):
    result = await Runner.run(maintenance_agent, "How do I do maintenance in AC induction motor?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Maintenance Assistant", ...)
# - Final output (str):
#     Here’s a concise maintenance checklist for a three-phase AC induction motor:
#
#     Safety first
#     - Lockout/tagout and ensure power is off before any work.
#     -Wear PPE; verify capacitor banks are discharged.
#
#     Daily/shift
#     - Visual: check for unusual vibration, noise, overheating, oil leaks.
#     - Check mounting and belt/pulley alignment (if a belt-driven motor).
#
#     Electrical checks (periodic)
#     - Inspect terminals for loose connections; tighten to spec.
#     - Measure insulation resistance (Megger) and compare to baseline.
#     - Inspect protection devices (overload relays, fuses) and wiring for signs of overheating.
#
#     Mechanical checks (periodic)
#     - Bearings: listen for roughness, check for play, abnormal temperatures. Lubricate per manufacturer:
#       - Grease or oil type, quantity, interval. Do not over-grease.
# ...

# %%
response_stream = Runner.run_streamed(maintenance_agent, "How do I do maintenance in AC induction motor?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Here’s a concise maintenance checklist for an AC induction motor (standard squirrel-cage or wound-rotor):
#
# Safety first
# - Lockout/tagout, disconnect power, verify de-energized.
#
# Routine (daily/weekly)
# - Listen for abnormal noises, vibration, overheating.
# - Check cooling system: vents clear, fan unobstructed.
#
# Electrical and insulation checks (monthly)
# - Inspect terminal connections for looseness; tighten if needed.
# - Check insulation condition (warm surfaces, unusual odors; insulation resistance test if available).
#
# Bearings and lubrication (every 6–12 months or per manufacturer)
# - Inspect bearing housings for oil leaks or contamination.
# - Lubricate with the recommended grease/oil and amount; avoid over-lubrication.
# - Check bearing temperature during run; look for overheating.
#
# Mechanical alignment and mounting (annual or after relocation)
# - Verify shaft alignment between motor and driven equipment.
# ...

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """,
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are a healthy, convenient fruit. They provide:
#
#     - Potassium (good for blood pressure), vitamin C, vitamin B6, and fiber
#     - About 90–110 kcal per medium banana; natural sugars with fiber slow-release
#     - Some resistant starch when unripe (less ripe = higher starch)
#
#     Tips:
#     - One to two bananas daily fits a balanced diet for most people.
#     - If you have kidney disease or are watching potassium, check your intake with a clinician.
#     - Pair with protein or fat for satiety and better blood sugar control.
#
#     Overall: a nutritious, portable fruit—great as part of a varied diet.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)

# %%
indiantour_agent = Agent(
    name="Indian Tour Assistant",
    instructions="""
    You are a helpful assistant providing information about Indian famous tourist destinations.
    You give concise answers.answer should be right.Also mention best time to visit the place with duration of stay to cover all spots  and how to reach there.
    """,
)

# %%
with trace("Simple Indian Tour Agent"):
    result = await Runner.run(indiantour_agent, "which places to visit in idnia during summer season?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Indian Tour Assistant", ...)
# - Final output (str):
#     Here are some great Indian destinations to visit in summer, with quick guidance on best time, stay duration, and how to reach.
#
#     - Shimla (Himachal Pradesh)
#       - Best time in summer: March–June (pleasantly cool)
#       - Duration: 2–3 days (Mall Road, Jakhoo Temple, Kufri)
#       - How to reach: Rail to Kalka + toy train/road; or flight to Chandigarh then road
#
#     - Manali (Himachal Pradesh)
#       - Best time in summer: May–June (cool, scenic)
#       - Duration: 3–4 days (Hadimba Temple, Rohtang Pass (seasonal), Solang Valley)
#       - How to reach: Flight to Kullu-Manali (or Chandigarh), road transfer; or train to Jogindernagar then road
#
#     - Mussoorie (Uttarakhand)
#       - Best time in summer: March–June
#       - Duration: 2–3 days (The Mall, Kempty Falls, Gun Hill)
#       - How to reach: Train to Dehradun; road transfer
#
#     - Nainital (Uttarakhand)
# ...

# %%
response_stream = Runner.run_streamed(indiantour_agent, "What are the famous tourist destinations in India?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Here are some famous tourist destinations in India:
#
# - Taj Mahal, Agra
# - Jaipur (Pink City), Rajasthan
# - Varanasi, Uttar Pradesh
# - Kerala backwaters (Alappuzha/ Kumarakom)
# - Munnar and Thekkady, Kerala
# - Goa (beaches and nightlife)
# - Delhi (Qutub Minar, Red Fort, India Gate)
# - Amritsar (Golden Temple)
# - Leh-Ladakh (Sikkim? actually Ladakh)
# - Ranthambore National Park, Rajasthan
# - Hampi, Karnataka
# - Ooty and Kodaikanal, Tamil Nadu
# - Andaman and Nicobar Islands (Port Blair, Havelock)
# - Rishikesh and Haridwar (Spiritual/Yoga)
# - Mysore and Coorg, Karnataka
#
# If you want recommendations for a specific region or theme, tell me.

# %% [markdown]
# _Good Job!_
